# %% [markdown]
# ![DLSU_pic.PNG](attachment:DLSU_pic.PNG)

# %% [markdown]
# # <center>Data Cleaning and Data Modeling</center>
#
# Prepared by: Cesar P. Malenab Jr.

# %% [markdown]
# ## Database Schema

# %% [markdown]
# ![database%20schema-6.png](attachment:database%20schema-6.png)

# %% [markdown]
# ## Job Table

# %%
import pandas as pd
import numpy as np
import re
import warnings 

warnings.filterwarnings('ignore')

# %%
job_table = pd.read_csv('job_table.csv').iloc[:, 1:]

# %%
job_table
# Out:
#                                         Job Title  \
# 0                             IT Support Engineer
# 1                 Software Engineer (Entry Level)
# 2                 Data Engineer (Associate Level)
# 3     Cybersecurity Threat Engineer (Entry Level)
# 4         Software Engineer (February 2023 Class)
# ...                                           ...
# 1012      SENIOR PRODUCT ENGINEER (Tower & Power)
# 1013        AI Conversation Designer / Ontologist
# 1014                   Data Base Analyst Engineer
# 1015                      Senior Network Engineer
# 1016                   Java Developer (Mid-level)
#
#                                                 Company  \
# 0                                                TikTok
# 1                                        DXC Technology
# 2                                 MediLink Network Inc.
# 3                                           Trend Micro
# 4                              FactSet Research Systems
# ...                                                 ...
# 1012  Wuhan Fiberhome International Technologies Phi...
# 1013                           Career Professionals Inc
# 1014                      Leisure & Resorts World Corp.
# 1015                                     DXC Technology
# 1016                                 e-pon Digital Inc.
#
#                                       Company Rating Location  \
# 0                                                NaN   Manila
# 1     3.2 out of 5 stars from 3,865 employee ratings   Manila
# 2        3.1 out of 5 stars from 36 employee ratings   Makati
# 3         4 out of 5 stars from 194 employee ratings   Manila
# 4       3.8 out of 5 stars from 581 employee ratings   Manila
# ...                                              ...      ...
# 1012    3.4 out of 5 stars from 111 employee ratings   Makati
# 1013                                             NaN   Manila
# 1014      3.4 out of 5 stars from 7 employee ratings    Pasig
# 1015  3.2 out of 5 stars from 3,866 employee ratings   Manila
# 1016                                             NaN   Taguig
#
#                                Salary  \
# 0     PHP 20,838 - PHP 70,447 a month
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 1012                              NaN
# 1013                              NaN
# 1014                              NaN
# 1015                              NaN
# 1016                              NaN
#
#                                         Job Description
# 0     We are seeking an IT Support Engineer to suppo...
# 1     Job Description:\nEssential Job Functions\nCod...
# 2     Job Description:\nA Data Engineer(CL1) will he...
# 3     As the number of cyberattacks and digital thre...
# 4     The FactSet Engineering team is composed of hi...
# ...                                                 ...
# 1012  JOB REQUIREMENT:\nElectric, Telcom communicati...
# 1013  Job Functions:\nDevelopment of domain specific...
# 1014  More than 3 years of experience in large-scale...
# 1015  Service accountabilities:\nDesign – the design...
# 1016  Hello from e-pon team!\nWe are looking for Jav...
#
# [1017 rows x 6 columns]

# %%
job_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017 entries, 0 to 1016
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job Title        1017 non-null   object
#  1   Company          1017 non-null   object
#  2   Company Rating   497 non-null    object
#  3   Location         1017 non-null   object
#  4   Salary           215 non-null    object
#  5   Job Description  1017 non-null   object
# dtypes: object(6)
# memory usage: 47.8+ KB

# %%
job_table.duplicated().value_counts()
# Out:
# False    997
# True      20
# dtype: int64

# %%
job_table = job_table.drop_duplicates(ignore_index = True)

# %%
job_table
# Out:
#                                              Job Title  \
# 0                                  IT Support Engineer
# 1                      Software Engineer (Entry Level)
# 2                      Data Engineer (Associate Level)
# 3          Cybersecurity Threat Engineer (Entry Level)
# 4              Software Engineer (February 2023 Class)
# ..                                                 ...
# 992  Business Analyst and Quality Engineer ( 2 year...
# 993            SENIOR PRODUCT ENGINEER (Tower & Power)
# 994              AI Conversation Designer / Ontologist
# 995                         Data Base Analyst Engineer
# 996                         Java Developer (Mid-level)
#
#                                                Company  \
# 0                                               TikTok
# 1                                       DXC Technology
# 2                                MediLink Network Inc.
# 3                                          Trend Micro
# 4                             FactSet Research Systems
# ..                                                 ...
# 992                                  Hunter's Hub Inc.
# 993  Wuhan Fiberhome International Technologies Phi...
# 994                           Career Professionals Inc
# 995                      Leisure & Resorts World Corp.
# 996                                 e-pon Digital Inc.
#
#                                      Company Rating Location  \
# 0                                               NaN   Manila
# 1    3.2 out of 5 stars from 3,865 employee ratings   Manila
# 2       3.1 out of 5 stars from 36 employee ratings   Makati
# 3        4 out of 5 stars from 194 employee ratings   Manila
# 4      3.8 out of 5 stars from 581 employee ratings   Manila
# ..                                              ...      ...
# 992                                             NaN   Taguig
# 993    3.4 out of 5 stars from 111 employee ratings   Makati
# 994                                             NaN   Manila
# 995      3.4 out of 5 stars from 7 employee ratings    Pasig
# 996                                             NaN   Taguig
#
#                                Salary  \
# 0     PHP 20,838 - PHP 70,447 a month
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 992  PHP 95,000 - PHP 100,000 a month
# 993                               NaN
# 994                               NaN
# 995                               NaN
# 996                               NaN
#
#                                        Job Description
# 0    We are seeking an IT Support Engineer to suppo...
# 1    Job Description:\nEssential Job Functions\nCod...
# 2    Job Description:\nA Data Engineer(CL1) will he...
# 3    As the number of cyberattacks and digital thre...
# 4    The FactSet Engineering team is composed of hi...
# ..                                                 ...
# 992  Analyse the structure of a business, how it us...
# 993  JOB REQUIREMENT:\nElectric, Telcom communicati...
# 994  Job Functions:\nDevelopment of domain specific...
# 995  More than 3 years of experience in large-scale...
# 996  Hello from e-pon team!\nWe are looking for Jav...
#
# [997 rows x 6 columns]

# %% [markdown]
# ### Location

# %%
job_table['Location'].unique()
# Out:
# array(['Manila', 'Makati', 'Taguig', 'Quezon City', 'Mandaluyong',
#        'Pasig', 'Philippines', 'Muntinlupa', 'Pasay', 'Parañaque',
#        'Cavite City', 'Imus', 'Fort Bonifacio', 'Ortigas',
#        'General Trias', 'Alabang', 'Binondo', 'Navotas', 'Rosario',
#        'Kawit', 'Caloocan', 'Valenzuela', 'Eastwood City', 'Cubao',
#        'San Juan', 'Meycauayan', 'Cavite', 'Taytay', 'San Mateo',
#        'Antipolo'], dtype=object)

# %%
locations = {'Fort Bonifacio':'Taguig', 'Alabang':'Muntinlupa', 'Binondo':'Manila','Eastwood City':'Quezon City',
            'Cubao':'Quezon City', 'Ortigas':'Pasig', 'Cavite':'Cavite City', 'Cavite City':'Cavite City'}

# %%
job_table['Location'] = job_table['Location'].apply(
    lambda x: locations[x] 
    if any(loc in x for loc in locations.keys()) 
    else x)

# %%
job_table['Location'].unique()
# Out:
# array(['Manila', 'Makati', 'Taguig', 'Quezon City', 'Mandaluyong',
#        'Pasig', 'Philippines', 'Muntinlupa', 'Pasay', 'Parañaque',
#        'Cavite City', 'Imus', 'General Trias', 'Navotas', 'Rosario',
#        'Kawit', 'Caloocan', 'Valenzuela', 'San Juan', 'Meycauayan',
#        'Taytay', 'San Mateo', 'Antipolo'], dtype=object)

# %% [markdown]
# ### Company Rating

# %%
job_table['Rating'] = job_table['Company Rating'].apply(lambda x: x[:3] if pd.notnull(x) else np.nan)

job_table['Rating'] = pd.to_numeric(job_table['Rating'], errors = 'coerce')

# %%
job_table['No. of Raters'] = job_table['Company Rating'].apply(
    lambda x: re.findall(r'\d+', x)[-1]
    if pd.notnull(x) 
    else np.nan)

# %%
job_table
# Out:
#                                              Job Title  \
# 0                                  IT Support Engineer
# 1                      Software Engineer (Entry Level)
# 2                      Data Engineer (Associate Level)
# 3          Cybersecurity Threat Engineer (Entry Level)
# 4              Software Engineer (February 2023 Class)
# ..                                                 ...
# 992  Business Analyst and Quality Engineer ( 2 year...
# 993            SENIOR PRODUCT ENGINEER (Tower & Power)
# 994              AI Conversation Designer / Ontologist
# 995                         Data Base Analyst Engineer
# 996                         Java Developer (Mid-level)
#
#                                                Company  \
# 0                                               TikTok
# 1                                       DXC Technology
# 2                                MediLink Network Inc.
# 3                                          Trend Micro
# 4                             FactSet Research Systems
# ..                                                 ...
# 992                                  Hunter's Hub Inc.
# 993  Wuhan Fiberhome International Technologies Phi...
# 994                           Career Professionals Inc
# 995                      Leisure & Resorts World Corp.
# 996                                 e-pon Digital Inc.
#
#                                      Company Rating Location  \
# 0                                               NaN   Manila
# 1    3.2 out of 5 stars from 3,865 employee ratings   Manila
# 2       3.1 out of 5 stars from 36 employee ratings   Makati
# 3        4 out of 5 stars from 194 employee ratings   Manila
# 4      3.8 out of 5 stars from 581 employee ratings   Manila
# ..                                              ...      ...
# 992                                             NaN   Taguig
# 993    3.4 out of 5 stars from 111 employee ratings   Makati
# 994                                             NaN   Manila
# 995      3.4 out of 5 stars from 7 employee ratings    Pasig
# 996                                             NaN   Taguig
#
#                                Salary  \
# 0     PHP 20,838 - PHP 70,447 a month
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 992  PHP 95,000 - PHP 100,000 a month
# 993                               NaN
# 994                               NaN
# 995                               NaN
# 996                               NaN
#
#                                        Job Description  Rating No. of Raters
# 0    We are seeking an IT Support Engineer to suppo...     NaN           NaN
# 1    Job Description:\nEssential Job Functions\nCod...     3.2           865
# 2    Job Description:\nA Data Engineer(CL1) will he...     3.1            36
# 3    As the number of cyberattacks and digital thre...     NaN           194
# 4    The FactSet Engineering team is composed of hi...     3.8           581
# ..                                                 ...     ...           ...
# 992  Analyse the structure of a business, how it us...     NaN           NaN
# 993  JOB REQUIREMENT:\nElectric, Telcom communicati...     3.4           111
# 994  Job Functions:\nDevelopment of domain specific...     NaN           NaN
# 995  More than 3 years of experience in large-scale...     3.4             7
# 996  Hello from e-pon team!\nWe are looking for Jav...     NaN           NaN
#
# [997 rows x 8 columns]

# %% [markdown]
# ### Salary

# %%
def salary_min(x):
    if pd.notnull(x):
        salary = re.findall(r'\d+,\d+', x)
        if salary:
            salary = ''.join(salary[0].split(','))
            return salary
        else:
            return np.nan
    else:
        return np.nan

# %%
def salary_max(x):
    if pd.notnull(x):
        salary = re.findall(r'\d+,\d+', x)
        if len(salary) > 1:
            salary = ''.join(salary[1].split(','))
            return salary
        else:
            return np.nan
    else:
        return np.nan

# %%
job_table['Minimum Salary'] = job_table['Salary'].apply(lambda x: salary_min(x))

job_table['Maximum Salary'] = job_table['Salary'].apply(lambda x: salary_max(x))

# %% [markdown]
# ### Convert data types from string to int

# %%
columns = ['No. of Raters', 'Minimum Salary', 'Maximum Salary']

for column in columns:
    job_table[column] = job_table[column].astype('Int64')

# %%
job_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job Title        997 non-null    object
#  1   Company          997 non-null    object
#  2   Company Rating   487 non-null    object
#  3   Location         997 non-null    object
#  4   Salary           211 non-null    object
#  5   Job Description  997 non-null    object
#  6   Rating           407 non-null    float64
#  7   No. of Raters    487 non-null    Int64
#  8   Minimum Salary   211 non-null    Int64
#  9   Maximum Salary   163 non-null    Int64
# dtypes: Int64(3), float64(1), object(6)
# memory usage: 80.9+ KB

# %% [markdown]
# ### Rearranging the dataframe

# %%
job_table = job_table.drop(['Company Rating', 'Salary'], axis = 1)

# %%
column_names = ['Job Title', 'Company', 'Location', 'Rating', 'No. of Raters', 'Minimum Salary', 'Maximum Salary', 'Job Description']

job_table = job_table.reindex(columns = column_names)

# %%
job_table.head()
# Out:
#                                      Job Title                   Company  \
# 0                          IT Support Engineer                    TikTok
# 1              Software Engineer (Entry Level)            DXC Technology
# 2              Data Engineer (Associate Level)     MediLink Network Inc.
# 3  Cybersecurity Threat Engineer (Entry Level)               Trend Micro
# 4      Software Engineer (February 2023 Class)  FactSet Research Systems
#
#   Location  Rating  No. of Raters  Minimum Salary  Maximum Salary  \
# 0   Manila     NaN           <NA>           20838           70447
# 1   Manila     3.2            865            <NA>            <NA>
# 2   Makati     3.1             36            <NA>            <NA>
# 3   Manila     NaN            194            <NA>            <NA>
# 4   Manila     3.8            581            <NA>            <NA>
#
#                                      Job Description
# 0  We are seeking an IT Support Engineer to suppo...
# 1  Job Description:\nEssential Job Functions\nCod...
# 2  Job Description:\nA Data Engineer(CL1) will he...
# 3  As the number of cyberattacks and digital thre...
# 4  The FactSet Engineering team is composed of hi...

# %% [markdown]
# ## Company Table

# %%
company_table = pd.read_csv('company_table.csv').iloc[:, 1:]

# %%
company_table
# Out:
#                                                 Company  \
# 0                                                TikTok
# 1                                        DXC Technology
# 2                                 MediLink Network Inc.
# 3                                           Trend Micro
# 4                              FactSet Research Systems
# ...                                                 ...
# 1000  Wuhan Fiberhome International Technologies Phi...
# 1001                           Career Professionals Inc
# 1002                      Leisure & Resorts World Corp.
# 1003                                     DXC Technology
# 1004                                 e-pon Digital Inc.
#
#                         Industry                                      CEO  \
# 0        Management & Consulting                                      NaN
# 1         Information Technology  Mike Salvino, Chairman, President & CEO
# 2         Information Technology                                      NaN
# 3         Information Technology                                 Eva Chen
# 4         Information Technology                              Philip Snow
# ...                          ...                                      ...
# 1000          Telecommunications                                      NaN
# 1001  Human Resources & Staffing                                      NaN
# 1002                         NaN                                      NaN
# 1003      Information Technology  Mike Salvino, Chairman, President & CEO
# 1004          Financial Services                                      NaN
#
#           Company Size                      Revenue
# 0                  NaN                          NaN
# 1     more than 10,000    P5 billion to P10 billion
# 2           201 to 500                          NaN
# 3      5,001 to 10,000     P1 billion to P5 billion
# 4      5,001 to 10,000  P25 million to P100 million
# ...                ...                          ...
# 1000               NaN                          NaN
# 1001      less than 10     P1 million to P5 million
# 1002               NaN                          NaN
# 1003  more than 10,000    P5 billion to P10 billion
# 1004         51 to 200                          NaN
#
# [1005 rows x 5 columns]

# %%
company_table.duplicated().value_counts()
# Out:
# False    597
# True     408
# dtype: int64

# %%
company_table = company_table.drop_duplicates(ignore_index = True)

# %%
company_table[company_table['Company'].duplicated()]
# Out:
#                         Company                 Industry  CEO  \
# 115  Imperial Homes Corporation     Real Estate Agencies  NaN
# 143               Aurecon Group  Management & Consulting  NaN
# 585                     Amadeus   Information Technology  NaN
#
#          Company Size                     Revenue
# 115               NaN                         NaN
# 143   5,001 to 10,000  P500 million to P1 billion
# 585  more than 10,000    P1 billion to P5 billion

# %%
company_table[company_table['Company'] == 'Imperial Homes Corporation']
# Out:
#                         Company              Industry  CEO Company Size  \
# 107  Imperial Homes Corporation                   NaN  NaN          NaN
# 115  Imperial Homes Corporation  Real Estate Agencies  NaN          NaN
#
#     Revenue
# 107     NaN
# 115     NaN

# %%
company_table[company_table['Company'] == 'Aurecon Group']
# Out:
#            Company                          Industry  CEO     Company Size  \
# 60   Aurecon Group  Consulting and Business Services  NaN  5,001 to 10,000
# 143  Aurecon Group           Management & Consulting  NaN  5,001 to 10,000
#
#                         Revenue
# 60   P500 million to P1 billion
# 143  P500 million to P1 billion

# %%
company_table[company_table['Company'] == 'Amadeus']
# Out:
#      Company                Industry  CEO      Company Size  \
# 271  Amadeus      Retail & Wholesale  NaN               NaN
# 585  Amadeus  Information Technology  NaN  more than 10,000
#
#                       Revenue
# 271                       NaN
# 585  P1 billion to P5 billion

# %%
company_table = company_table.drop(index = [107, 143, 271]).reset_index(drop = True)

# %%
company_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       594 non-null    object
#  1   Industry      367 non-null    object
#  2   CEO           134 non-null    object
#  3   Company Size  256 non-null    object
#  4   Revenue       158 non-null    object
# dtypes: object(5)
# memory usage: 23.3+ KB

# %% [markdown]
# ### industry

# %%
company_table['Industry'].unique()
# Out:
# array(['Management & Consulting', 'Information Technology',
#        'Media & Communication', nan, 'Human Resources and Staffing',
#        'Construction', 'Human Resources & Staffing',
#        'Architectural & Engineering Services', 'Retail & Wholesale',
#        'Manufacturing', 'Energy, Mining & Utilities', 'Healthcare',
#        'Software Development', 'Telecommunications', '2013',
#        'Restaurants & Food Service',
#        'Medical Testing & Clinical Laboratories', 'Financial Services',
#        'Insurance', 'Information Technology Support Services',
#        'Consulting and Business Services', 'HR Consulting',
#        'Business Consulting', 'Real Estate', 'Internet & Web Services',
#        'Pharmaceutical & Biotechnology', 'Aerospace & Defense',
#        'Hotels & Travel Accommodation', 'Transportation & Logistics',
#        'Property Management', 'Real Estate Agencies',
#        'Internet and Software',
#        'Construction, Repair & Maintenance Services',
#        'Staffing & Subcontracting', 'Investment & Asset Management',
#        '1998', 'Electronics Manufacturing', '2010', '2017', 'Legal',
#        'Accounting & Tax', 'Education', 'Hospitals & Health Clinics',
#        'Food and Beverages', '2004', 'Consumer Product Manufacturing',
#        'Pharmaceutical', 'Catering & Food Service Contractors',
#        'Shipping & Trucking', 'Food & Beverage Manufacturing',
#        'Computer Hardware Development', 'Wholesale', '2018',
#        'Advertising & Public Relations', '2002',
#        'Airlines, Airports & Air Transportation', '2000',
#        'Wood & Paper Manufacturing'], dtype=object)

# %%
#remove 'year' industries

def edit_industry(comp):
    if comp is not np.nan:
        if comp.isdigit():
            return np.nan
        else:
            return comp
    else:
        return comp

# %%
company_table['Industry'] = company_table['Industry'].map(edit_industry)

# %%
company_table
# Out:
#                                                Company  \
# 0                                               TikTok
# 1                                       DXC Technology
# 2                                MediLink Network Inc.
# 3                                          Trend Micro
# 4                             FactSet Research Systems
# ..                                                 ...
# 589                                      Bold Business
# 590                      JDS Construction Phils., Inc.
# 591  Wuhan Fiberhome International Technologies Phi...
# 592                      Leisure & Resorts World Corp.
# 593                                 e-pon Digital Inc.
#
#                     Industry                                      CEO  \
# 0    Management & Consulting                                      NaN
# 1     Information Technology  Mike Salvino, Chairman, President & CEO
# 2     Information Technology                                      NaN
# 3     Information Technology                                 Eva Chen
# 4     Information Technology                              Philip Snow
# ..                       ...                                      ...
# 589      Business Consulting                                      NaN
# 590                      NaN                                      NaN
# 591       Telecommunications                                      NaN
# 592                      NaN                                      NaN
# 593       Financial Services                                      NaN
#
#          Company Size                      Revenue
# 0                 NaN                          NaN
# 1    more than 10,000    P5 billion to P10 billion
# 2          201 to 500                          NaN
# 3     5,001 to 10,000     P1 billion to P5 billion
# 4     5,001 to 10,000  P25 million to P100 million
# ..                ...                          ...
# 589               NaN                          NaN
# 590               NaN                          NaN
# 591               NaN                          NaN
# 592               NaN                          NaN
# 593         51 to 200                          NaN
#
# [594 rows x 5 columns]

# %%
#reduce industry dimensionality

company_table['Industry'].value_counts()
# Out:
# Information Technology                         78
# Human Resources & Staffing                     29
# Construction, Repair & Maintenance Services    23
# Manufacturing                                  23
# Retail & Wholesale                             21
# Financial Services                             20
# Management & Consulting                        19
# Telecommunications                             16
# Transportation & Logistics                     10
# Real Estate                                    10
# Media & Communication                           9
# Software Development                            9
# Energy, Mining & Utilities                      8
# Construction                                    7
# Architectural & Engineering Services            6
# Staffing & Subcontracting                       6
# Property Management                             5
# HR Consulting                                   5
# Business Consulting                             5
# Insurance                                       4
# Internet & Web Services                         3
# Hotels & Travel Accommodation                   3
# Aerospace & Defense                             3
# Healthcare                                      3
# Information Technology Support Services         3
# Restaurants & Food Service                      3
# Pharmaceutical & Biotechnology                  2
# Food & Beverage Manufacturing                   2
# Consumer Product Manufacturing                  2
# Education                                       2
# Internet and Software                           2
# Pharmaceutical                                  1
# Airlines, Airports & Air Transportation         1
# Advertising & Public Relations                  1
# Wholesale                                       1
# Computer Hardware Development                   1
# Medical Testing & Clinical Laboratories         1
# Shipping & Trucking                             1
# Catering & Food Service Contractors             1
# Real Estate Agencies                            1
# Human Resources and Staffing                    1
# Food and Beverages                              1
# Hospitals & Health Clinics                      1
# Consulting and Business Services                1
# Accounting & Tax                                1
# Legal                                           1
# Electronics Manufacturing                       1
# Investment & Asset Management                   1
# Wood & Paper Manufacturing                      1
# Name: Industry, dtype: int64

# %%
industries = {'Information and Communications Technology': ['Information Technology', 'Telecommunications', 
                                                            'Media & Communication', 'Software Development', 
                                                            'Internet & Web Services','Information Technology Support Services', 
                                                            'Internet and Software', 'Computer Hardware Development'],
             'Construction and Architecural Services':['Construction, Repair & Maintenance Services', 'Construction', 
                                                       'Architectural & Engineering Services'],
             'Manufacturing':['Manufacturing', 'Food & Beverage Manufacturing', 'Consumer Product Manufacturing', 
                               'Electronics Manufacturing', 'Wood & Paper Manufacturing'],
              
             'Transportation and Utilities':['Transportation & Logistics', 'Energy, Mining & Utilities', 
                                             'Airlines, Airports & Air Transportation', 'Shipping & Trucking'],
              'Administration and Business Support':['Human Resources & Staffing', 'Management & Consulting', 
                                                     'Staffing & Subcontracting', 'Property Management',
                                                    'HR Consulting', 'Business Consulting', 'Advertising & Public Relations',
                                                    'Human Resources and Staffing', 'Consulting and Business Services'],
              'Retail and Wholesale Trade':['Retail & Wholesale','Wholesale'],
              'Financial and Insurance Services': ['Financial Services', 'Insurance', 'Investment & Asset Management'],
              'Real Estate':['Real Estate', 'Real Estate Agencies'],
              'Accomodation and Food Services':['Hotels & Travel Accommodation','Restaurants & Food Service','Catering & Food Service Contractors',
                                               'Food and Beverages'],
              'Healthcare and Social Assistance':['Healthcare', 'Pharmaceutical & Biotechnology', 'Pharmaceutical', 'Medical Testing & Clinical Laboratories',
                                                 'Hospitals & Health Clinics'],
              'Others':['Aerospace & Defense', 'Accounting & Tax', 'Legal', 'Education']             
             }

# %%
def bin_industry(ind):
    if ind is not np.nan:
        for group, industry in industries.items():
            if ind in industry:
                return group
            else:
                continue
    else:
        return ind

# %%
company_table['Industry'] = company_table['Industry'].map(bin_industry)

# %%
company_table['Industry'].isnull().value_counts()
# Out:
# False    359
# True     235
# Name: Industry, dtype: int64

# %%
company_table
# Out:
#                                                Company  \
# 0                                               TikTok
# 1                                       DXC Technology
# 2                                MediLink Network Inc.
# 3                                          Trend Micro
# 4                             FactSet Research Systems
# ..                                                 ...
# 589                                      Bold Business
# 590                      JDS Construction Phils., Inc.
# 591  Wuhan Fiberhome International Technologies Phi...
# 592                      Leisure & Resorts World Corp.
# 593                                 e-pon Digital Inc.
#
#                                       Industry  \
# 0          Administration and Business Support
# 1    Information and Communications Technology
# 2    Information and Communications Technology
# 3    Information and Communications Technology
# 4    Information and Communications Technology
# ..                                         ...
# 589        Administration and Business Support
# 590                                        NaN
# 591  Information and Communications Technology
# 592                                        NaN
# 593           Financial and Insurance Services
#
#                                          CEO      Company Size  \
# 0                                        NaN               NaN
# 1    Mike Salvino, Chairman, President & CEO  more than 10,000
# 2                                        NaN        201 to 500
# 3                                   Eva Chen   5,001 to 10,000
# 4                                Philip Snow   5,001 to 10,000
# ..                                       ...               ...
# 589                                      NaN               NaN
# 590                                      NaN               NaN
# 591                                      NaN               NaN
# 592                                      NaN               NaN
# 593                                      NaN         51 to 200
#
#                          Revenue
# 0                            NaN
# 1      P5 billion to P10 billion
# 2                            NaN
# 3       P1 billion to P5 billion
# 4    P25 million to P100 million
# ..                           ...
# 589                          NaN
# 590                          NaN
# 591                          NaN
# 592                          NaN
# 593                          NaN
#
# [594 rows x 5 columns]

# %%
industry_table = pd.DataFrame(company_table['Industry'].unique(), columns =['industry'])

# %%
industry_table
# Out:
#                                      industry
# 0         Administration and Business Support
# 1   Information and Communications Technology
# 2                                         NaN
# 3      Construction and Architecural Services
# 4                  Retail and Wholesale Trade
# 5                               Manufacturing
# 6                Transportation and Utilities
# 7            Healthcare and Social Assistance
# 8              Accomodation and Food Services
# 9            Financial and Insurance Services
# 10                                Real Estate
# 11                                     Others

# %%
industry_table = industry_table.dropna().reset_index(drop = True)

# %%
industry_table.index.name = 'industry_id'

# %%
industry_table
# Out:
#                                               industry
# industry_id
# 0                  Administration and Business Support
# 1            Information and Communications Technology
# 2               Construction and Architecural Services
# 3                           Retail and Wholesale Trade
# 4                                        Manufacturing
# 5                         Transportation and Utilities
# 6                     Healthcare and Social Assistance
# 7                       Accomodation and Food Services
# 8                     Financial and Insurance Services
# 9                                          Real Estate
# 10                                              Others

# %% [markdown]
# ### Company Size

# %%
company_table['Company Size'].unique()
# Out:
# array([nan, 'more than 10,000', '201 to 500', '5,001 to 10,000',
#        'less than 10', '501 to 1,000', '51 to 200', '11 to 50',
#        '1001 to 5,000', 'P500 million to P1 billion'], dtype=object)

# %%
#do not include the last element (P500 million to P1 billion)

company_size = sorted(company_table['Company Size'].unique()[1:-1], key = len)
company_size
# Out:
# ['11 to 50',
#  '51 to 200',
#  '201 to 500',
#  'less than 10',
#  '501 to 1,000',
#  '1001 to 5,000',
#  '5,001 to 10,000',
#  'more than 10,000']

# %%
company_size.remove('less than 10')
company_size.insert(0,'less than 10')
company_size
# Out:
# ['less than 10',
#  '11 to 50',
#  '51 to 200',
#  '201 to 500',
#  '501 to 1,000',
#  '1001 to 5,000',
#  '5,001 to 10,000',
#  'more than 10,000']

# %%
company_size_table = pd.DataFrame(company_size, columns =['company_size'])
company_size_table.index.name = 'company_size_id'
company_size_table
# Out:
#                      company_size
# company_size_id
# 0                    less than 10
# 1                        11 to 50
# 2                       51 to 200
# 3                      201 to 500
# 4                    501 to 1,000
# 5                   1001 to 5,000
# 6                 5,001 to 10,000
# 7                more than 10,000

# %%
#replace wrong company size
company_table[company_table['Company Size'] == 'P500 million to P1 billion']
# Out:
#                        Company       Industry                CEO  \
# 147  Allegro MicroSystems, LLC  Manufacturing  Vineet Nargolwala
#
#                    Company Size Revenue
# 147  P500 million to P1 billion     NaN

# %%
company_table['Company Size'][147] = np.nan

# %%
#P500 million to P1 billion removed

company_table['Company Size'].unique()
# Out:
# array([nan, 'more than 10,000', '201 to 500', '5,001 to 10,000',
#        'less than 10', '501 to 1,000', '51 to 200', '11 to 50',
#        '1001 to 5,000'], dtype=object)

# %% [markdown]
# ### Revenue

# %%
company_table['Revenue'].unique()
# Out:
# array([nan, 'P5 billion to P10 billion', 'P1 billion to P5 billion',
#        'P25 million to P100 million', 'P100 million to P500 million',
#        'P1 million to P5 million', 'more than $10B (USD)',
#        'P500 million to P1 billion', 'P5 million to P25 million',
#        'less than $1M (USD)'], dtype=object)

# %%
revenue = sorted(company_table['Revenue'].unique()[1:], key = len)

# %%
revenue_table = pd.DataFrame(revenue, columns =['revenue'])
revenue_table.index.name = 'revenue_id'

# %%
revenue_table
# Out:
#                                  revenue
# revenue_id
# 0                    less than $1M (USD)
# 1                   more than $10B (USD)
# 2               P1 billion to P5 billion
# 3               P1 million to P5 million
# 4              P5 billion to P10 billion
# 5              P5 million to P25 million
# 6             P500 million to P1 billion
# 7            P25 million to P100 million
# 8           P100 million to P500 million

# %% [markdown]
# ### Replace industry, company size, revenue in company table with foreign keys

# %%
#industry

company_table['Industry'].isnull().value_counts()
# Out:
# False    359
# True     235
# Name: Industry, dtype: int64

# %%
company_table['Industry'] = company_table['Industry'].map(
    lambda x: industry_table[industry_table['industry'] == x].index[0] 
    if x is not np.nan 
    else x).astype('Int64')

# %%
#company size
company_table['Company Size'] = company_table['Company Size'].map(
    lambda x: company_size_table[company_size_table['company_size'] == x].index[0] 
    if x is not np.nan 
    else x).astype('Int64')

# %%
#revenue 
company_table['Revenue'] = company_table['Revenue'].map(
    lambda x: revenue_table[revenue_table['revenue'] == x].index[0] 
    if x is not np.nan 
    else x).astype('Int64')

# %%
company_table
# Out:
#                                                Company  Industry  \
# 0                                               TikTok         0
# 1                                       DXC Technology         1
# 2                                MediLink Network Inc.         1
# 3                                          Trend Micro         1
# 4                             FactSet Research Systems         1
# ..                                                 ...       ...
# 589                                      Bold Business         0
# 590                      JDS Construction Phils., Inc.      <NA>
# 591  Wuhan Fiberhome International Technologies Phi...         1
# 592                      Leisure & Resorts World Corp.      <NA>
# 593                                 e-pon Digital Inc.         8
#
#                                          CEO  Company Size  Revenue
# 0                                        NaN          <NA>     <NA>
# 1    Mike Salvino, Chairman, President & CEO             7        4
# 2                                        NaN             3     <NA>
# 3                                   Eva Chen             6        2
# 4                                Philip Snow             6        7
# ..                                       ...           ...      ...
# 589                                      NaN          <NA>     <NA>
# 590                                      NaN          <NA>     <NA>
# 591                                      NaN          <NA>     <NA>
# 592                                      NaN          <NA>     <NA>
# 593                                      NaN             2     <NA>
#
# [594 rows x 5 columns]

# %% [markdown]
# ### Move company rating to company table

# %%
ratings = job_table[['Company', 'Rating', 'No. of Raters']]

# %%
ratings['Company'].duplicated().value_counts()
# Out:
# False    600
# True     397
# Name: Company, dtype: int64

# %%
ratings['Company'] = ratings['Company'].drop_duplicates()

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        600 non-null    object
#  1   Rating         407 non-null    float64
#  2   No. of Raters  487 non-null    Int64
# dtypes: Int64(1), float64(1), object(1)
# memory usage: 24.5+ KB

# %%
company_table = pd.merge(company_table, ratings, how = 'left', on = 'Company')

# %%
company_table
# Out:
#                                                Company  Industry  \
# 0                                               TikTok         0
# 1                                       DXC Technology         1
# 2                                MediLink Network Inc.         1
# 3                                          Trend Micro         1
# 4                             FactSet Research Systems         1
# ..                                                 ...       ...
# 589                                      Bold Business         0
# 590                      JDS Construction Phils., Inc.      <NA>
# 591  Wuhan Fiberhome International Technologies Phi...         1
# 592                      Leisure & Resorts World Corp.      <NA>
# 593                                 e-pon Digital Inc.         8
#
#                                          CEO  Company Size  Revenue  Rating  \
# 0                                        NaN          <NA>     <NA>     NaN
# 1    Mike Salvino, Chairman, President & CEO             7        4     3.2
# 2                                        NaN             3     <NA>     3.1
# 3                                   Eva Chen             6        2     NaN
# 4                                Philip Snow             6        7     3.8
# ..                                       ...           ...      ...     ...
# 589                                      NaN          <NA>     <NA>     3.3
# 590                                      NaN          <NA>     <NA>     3.1
# 591                                      NaN          <NA>     <NA>     3.4
# 592                                      NaN          <NA>     <NA>     3.4
# 593                                      NaN             2     <NA>     NaN
#
#      No. of Raters
# 0             <NA>
# 1              865
# 2               36
# 3              194
# 4              581
# ..             ...
# 589              9
# 590              9
# 591            111
# 592              7
# 593           <NA>
#
# [594 rows x 7 columns]

# %% [markdown]
# ### Add companies without links in Indeed in the company table

# %%
missing_companies = set()

for comp in list(job_table['Company']):
    if comp not in list(company_table['Company']):
        missing_companies.add(comp)
        
missing_companies
# Out:
# {'Publicis Re:Sources Global',
#  'THE BELT AND ROAD SINOBRIDGE (PHILIPPINES) INTERNATIONAL ECONOMIC AND TALENTS COOPERATION CENTER',
#  'Talentview for Penbrothers',
#  'Tamaray People Solutions',
#  'Tri-Unity Talent Sourcing & Human Resource Management Services',
#  'Universal Access & Systems Solutions'}

# %%
for comp in missing_companies:
    row = pd.DataFrame({'Company':[comp]})
    company_table = pd.concat([company_table,row], ignore_index = True)

# %%
company_table
# Out:
#                                                Company  Industry  \
# 0                                               TikTok         0
# 1                                       DXC Technology         1
# 2                                MediLink Network Inc.         1
# 3                                          Trend Micro         1
# 4                             FactSet Research Systems         1
# ..                                                 ...       ...
# 595  THE BELT AND ROAD SINOBRIDGE (PHILIPPINES) INT...      <NA>
# 596                         Publicis Re:Sources Global      <NA>
# 597               Universal Access & Systems Solutions      <NA>
# 598                           Tamaray People Solutions      <NA>
# 599  Tri-Unity Talent Sourcing & Human Resource Man...      <NA>
#
#                                          CEO  Company Size  Revenue  Rating  \
# 0                                        NaN          <NA>     <NA>     NaN
# 1    Mike Salvino, Chairman, President & CEO             7        4     3.2
# 2                                        NaN             3     <NA>     3.1
# 3                                   Eva Chen             6        2     NaN
# 4                                Philip Snow             6        7     3.8
# ..                                       ...           ...      ...     ...
# 595                                      NaN          <NA>     <NA>     NaN
# 596                                      NaN          <NA>     <NA>     NaN
# 597                                      NaN          <NA>     <NA>     NaN
# 598                                      NaN          <NA>     <NA>     NaN
# 599                                      NaN          <NA>     <NA>     NaN
#
#      No. of Raters
# 0             <NA>
# 1              865
# 2               36
# 3              194
# 4              581
# ..             ...
# 595           <NA>
# 596           <NA>
# 597           <NA>
# 598           <NA>
# 599           <NA>
#
# [600 rows x 7 columns]

# %% [markdown]
# ### Remove rating and no of raters column in job_table

# %%
job_table = job_table.drop(['Rating', 'No. of Raters'], axis = 1)

# %%
job_table.head()
# Out:
#                                      Job Title                   Company  \
# 0                          IT Support Engineer                    TikTok
# 1              Software Engineer (Entry Level)            DXC Technology
# 2              Data Engineer (Associate Level)     MediLink Network Inc.
# 3  Cybersecurity Threat Engineer (Entry Level)               Trend Micro
# 4      Software Engineer (February 2023 Class)  FactSet Research Systems
#
#   Location  Minimum Salary  Maximum Salary  \
# 0   Manila           20838           70447
# 1   Manila            <NA>            <NA>
# 2   Makati            <NA>            <NA>
# 3   Manila            <NA>            <NA>
# 4   Manila            <NA>            <NA>
#
#                                      Job Description
# 0  We are seeking an IT Support Engineer to suppo...
# 1  Job Description:\nEssential Job Functions\nCod...
# 2  Job Description:\nA Data Engineer(CL1) will he...
# 3  As the number of cyberattacks and digital thre...
# 4  The FactSet Engineering team is composed of hi...

# %% [markdown]
# ## Location Table

# %% [markdown]
# data downloaded from: https://simplemaps.com/data/ph-cities

# %%
location_table = pd.read_csv('ph.csv')

# %%
location_table
# Out:
#                city      lat       lng      country iso2       admin_name  \
# 0            Manila  14.6000  120.9833  Philippines   PH           Manila
# 1       Quezon City  14.6333  121.0333  Philippines   PH           Quezon
# 2             Davao   7.0667  125.6000  Philippines   PH            Davao
# 3     Caloocan City  14.6500  120.9667  Philippines   PH         Caloocan
# 4         Cebu City  10.3000  123.9000  Philippines   PH             Cebu
# ...             ...      ...       ...          ...  ...              ...
# 1002      Koronadal   6.2541  124.9922  Philippines   PH   South Cotabato
# 1003       San Jose  10.1800  125.5683  Philippines   PH  Dinagat Islands
# 1004          Tabuk  17.4084  121.2785  Philippines   PH          Kalinga
# 1005           Pili  13.7177  123.7448  Philippines   PH    Camarines Sur
# 1006     Madridejos   9.7912  123.3462  Philippines   PH             Cebu
#
#       capital  population  population_proper
# 0     primary  23088000.0          1780148.0
# 1       admin   2936116.0          2936116.0
# 2       admin   1632991.0          1632991.0
# 3       admin   1583978.0          1583978.0
# 4       admin    922611.0           922611.0
# ...       ...         ...                ...
# 1002    admin         NaN                NaN
# 1003    admin         NaN                NaN
# 1004    admin         NaN                NaN
# 1005    admin         NaN                NaN
# 1006    minor         NaN                NaN
#
# [1007 rows x 9 columns]

# %%
column_names = ['country', 'iso2', 'capital', 'population','population_proper']
location_table = location_table.drop(columns=column_names)

# %%
#Add Philippines to dataframe for work-from-home jobs

row = pd.DataFrame({'city':['Philippines']})
location_table = pd.concat([location_table, row], ignore_index = True)

# %%
location_table.columns = ['city_name', 'latitude', 'longitude','admin_name']
location_table.index.name = 'location_id'

# %%
location_table
# Out:
#                  city_name  latitude  longitude       admin_name
# location_id
# 0                   Manila   14.6000   120.9833           Manila
# 1              Quezon City   14.6333   121.0333           Quezon
# 2                    Davao    7.0667   125.6000            Davao
# 3            Caloocan City   14.6500   120.9667         Caloocan
# 4                Cebu City   10.3000   123.9000             Cebu
# ...                    ...       ...        ...              ...
# 1003              San Jose   10.1800   125.5683  Dinagat Islands
# 1004                 Tabuk   17.4084   121.2785          Kalinga
# 1005                  Pili   13.7177   123.7448    Camarines Sur
# 1006            Madridejos    9.7912   123.3462             Cebu
# 1007           Philippines       NaN        NaN              NaN
#
# [1008 rows x 4 columns]

# %% [markdown]
# ### Replace location and company in job table with foreign keys
# ### location_id

# %%
job_table['Location'] = job_table['Location'].apply(
    lambda x: location_table[(location_table['city_name'] == x) | (location_table['admin_name'] == x)].index[0])

# %% [markdown]
# ### company_id

# %%
job_table['Company'] = job_table['Company'].map(
    lambda x: company_table[company_table['Company'] == x].index[0])

# %% [markdown]
# ### Rename columns of job and company tables

# %%
job_table.columns = ['job_title', 'company_id', 'location_id', 'minimum_salary', 'maximum_salary', 'job_description']
job_table.index.name = 'job_id'

# %%
job_table
# Out:
#                                                 job_title  company_id  \
# job_id
# 0                                     IT Support Engineer           0
# 1                         Software Engineer (Entry Level)           1
# 2                         Data Engineer (Associate Level)           2
# 3             Cybersecurity Threat Engineer (Entry Level)           3
# 4                 Software Engineer (February 2023 Class)           4
# ...                                                   ...         ...
# 992     Business Analyst and Quality Engineer ( 2 year...          62
# 993               SENIOR PRODUCT ENGINEER (Tower & Power)         591
# 994                 AI Conversation Designer / Ontologist          45
# 995                            Data Base Analyst Engineer         592
# 996                            Java Developer (Mid-level)         593
#
#         location_id  minimum_salary  maximum_salary  \
# job_id
# 0                 0           20838           70447
# 1                 0            <NA>            <NA>
# 2                16            <NA>            <NA>
# 3                 0            <NA>            <NA>
# 4                 0            <NA>            <NA>
# ...             ...             ...             ...
# 992               6           95000          100000
# 993              16            <NA>            <NA>
# 994               0            <NA>            <NA>
# 995               8            <NA>            <NA>
# 996               6            <NA>            <NA>
#
#                                           job_description
# job_id
# 0       We are seeking an IT Support Engineer to suppo...
# 1       Job Description:\nEssential Job Functions\nCod...
# 2       Job Description:\nA Data Engineer(CL1) will he...
# 3       As the number of cyberattacks and digital thre...
# 4       The FactSet Engineering team is composed of hi...
# ...                                                   ...
# 992     Analyse the structure of a business, how it us...
# 993     JOB REQUIREMENT:\nElectric, Telcom communicati...
# 994     Job Functions:\nDevelopment of domain specific...
# 995     More than 3 years of experience in large-scale...
# 996     Hello from e-pon team!\nWe are looking for Jav...
#
# [997 rows x 6 columns]

# %%
company_table.columns = ['company_name', 'industry_id', 'ceo','company_size_id', 'revenue_id', 'company_rating', 
                         'no_of_raters']
company_table.index.name = 'company_id'

# %%
company_table
# Out:
#                                                  company_name  industry_id  \
# company_id
# 0                                                      TikTok            0
# 1                                              DXC Technology            1
# 2                                       MediLink Network Inc.            1
# 3                                                 Trend Micro            1
# 4                                    FactSet Research Systems            1
# ...                                                       ...          ...
# 595         THE BELT AND ROAD SINOBRIDGE (PHILIPPINES) INT...         <NA>
# 596                                Publicis Re:Sources Global         <NA>
# 597                      Universal Access & Systems Solutions         <NA>
# 598                                  Tamaray People Solutions         <NA>
# 599         Tri-Unity Talent Sourcing & Human Resource Man...         <NA>
#
#                                                 ceo  company_size_id  \
# company_id
# 0                                               NaN             <NA>
# 1           Mike Salvino, Chairman, President & CEO                7
# 2                                               NaN                3
# 3                                          Eva Chen                6
# 4                                       Philip Snow                6
# ...                                             ...              ...
# 595                                             NaN             <NA>
# 596                                             NaN             <NA>
# 597                                             NaN             <NA>
# 598                                             NaN             <NA>
# 599                                             NaN             <NA>
#
#             revenue_id  company_rating  no_of_raters
# company_id
# 0                 <NA>             NaN          <NA>
# 1                    4             3.2           865
# 2                 <NA>             3.1            36
# 3                    2             NaN           194
# 4                    7             3.8           581
# ...                ...             ...           ...
# 595               <NA>             NaN          <NA>
# 596               <NA>             NaN          <NA>
# 597               <NA>             NaN          <NA>
# 598               <NA>             NaN          <NA>
# 599               <NA>             NaN          <NA>
#
# [600 rows x 7 columns]

# %% [markdown]
# ### Review other tables

# %%
industry_table
# Out:
#                                               industry
# industry_id
# 0                  Administration and Business Support
# 1            Information and Communications Technology
# 2               Construction and Architecural Services
# 3                           Retail and Wholesale Trade
# 4                                        Manufacturing
# 5                         Transportation and Utilities
# 6                     Healthcare and Social Assistance
# 7                       Accomodation and Food Services
# 8                     Financial and Insurance Services
# 9                                          Real Estate
# 10                                              Others

# %%
company_size_table
# Out:
#                      company_size
# company_size_id
# 0                    less than 10
# 1                        11 to 50
# 2                       51 to 200
# 3                      201 to 500
# 4                    501 to 1,000
# 5                   1001 to 5,000
# 6                 5,001 to 10,000
# 7                more than 10,000

# %%
location_table
# Out:
#                  city_name  latitude  longitude       admin_name
# location_id
# 0                   Manila   14.6000   120.9833           Manila
# 1              Quezon City   14.6333   121.0333           Quezon
# 2                    Davao    7.0667   125.6000            Davao
# 3            Caloocan City   14.6500   120.9667         Caloocan
# 4                Cebu City   10.3000   123.9000             Cebu
# ...                    ...       ...        ...              ...
# 1003              San Jose   10.1800   125.5683  Dinagat Islands
# 1004                 Tabuk   17.4084   121.2785          Kalinga
# 1005                  Pili   13.7177   123.7448    Camarines Sur
# 1006            Madridejos    9.7912   123.3462             Cebu
# 1007           Philippines       NaN        NaN              NaN
#
# [1008 rows x 4 columns]

# %% [markdown]
# ### Create tables in database using psycopg2 and insert values using SQLAlchemy

# %%
import psycopg2

# %%
conn = psycopg2.connect('host = 127.0.0.1 dbname = data_engineering_job_ads user = Cesar_Malenab  password = finalpaper')
conn.set_session(autocommit = True)
cur = conn.cursor()

# %%
from sqlalchemy import create_engine
conn_df = 'postgresql+psycopg2://Cesar_Malenab:finalpaper@127.0.0.1/data_engineering_job_ads'

# %%
query = '''
            CREATE TABLE industry(
                industry_id SERIAL PRIMARY KEY,
                industry VARCHAR(100) UNIQUE NOT NULL
            );
         '''

cur.execute(query)

# %%
industry_table.to_sql('industry', con = conn_df, if_exists='append')
# Out:
# 11

# %%
query = '''
            CREATE TABLE company_size(
                company_size_id SERIAL PRIMARY KEY,
                company_size VARCHAR(100) UNIQUE NOT NULL
            );
         '''

cur.execute(query)

# %%
company_size_table.to_sql('company_size', con = conn_df, if_exists='append')
# Out:
# 8

# %%
query = '''
            CREATE TABLE revenue(
                revenue_id SERIAL PRIMARY KEY,
                revenue VARCHAR(100) UNIQUE NOT NULL
            );
         '''

cur.execute(query)

# %%
revenue_table.to_sql('revenue', con = conn_df, if_exists='append')
# Out:
# 9

# %%
query = '''
            CREATE TABLE location(
                location_id SERIAL PRIMARY KEY,
                city_name VARCHAR(100) NOT NULL,
                latitude DECIMAL,
                longitude DECIMAL,
                admin_name VARCHAR(100)
            );
         '''

cur.execute(query)

# %%
location_table.to_sql('location', con = conn_df, if_exists='append')
# Out:
# 8

# %%
query = '''
            CREATE TABLE company(
                company_id SERIAL PRIMARY KEY,
                company_name VARCHAR(100) UNIQUE NOT NULL,
                industry_id INTEGER REFERENCES industry(industry_id),
                ceo VARCHAR(100),
                company_size_id INTEGER REFERENCES company_size(company_size_id),
                revenue_id INTEGER REFERENCES revenue(revenue_id),
                company_rating INTEGER,
                no_of_raters INTEGER
            );
         '''

cur.execute(query)

# %%
company_table.to_sql('company', con = conn_df, if_exists='append')
# Out:
# 600

# %%
query = '''
            CREATE TABLE job_post(
                job_id SERIAL PRIMARY KEY,
                job_title VARCHAR(100) NOT NULL,
                company_id INTEGER REFERENCES company(company_id),
                location_id INTEGER REFERENCES location(location_id),
                minimum_salary INTEGER,
                maximum_salary INTEGER,
                job_description TEXT
            );
         '''

cur.execute(query)

# %%
job_table.to_sql('job_post', con = conn_df, if_exists='append')
# Out:
# 997

# %% [markdown]
# ---
